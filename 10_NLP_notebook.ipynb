# %% [markdown]
# <a href="https://colab.research.google.com/github/alfondace/ISYS5002/blob/main/10_NLP_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Natural Language Processing
#
# * NLP is performed on **text collections** (**corpora**, plural of **corpus**):
#     * Tweets
#     * Facebook posts
#     * Conversations
#     * Movie reviews
#     * Documents
#     * Books
#     * News
#     * And more
# * **Nuances of meaning** make natural language understanding difficult
#     * Text’s meaning can be influenced by **context** and **reader’s “world view”**
#
#
# natural language toolkit (nltk)
#
# Python nltk package has modules for working with human language data.

# %% [markdown]
# ## 1 - Extracting text from Web - Web Scraping

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.techtarget.com/searchsap/news/252515342/Unilever-pursues-supply-chain-sustainability-with-blockchain"
#url = "https://edition.cnn.com/2020/09/13/tech/microsoft-tiktok-bytedance/index.html"

response = requests.get(url)
#print(response.url, "\n")

soup = BeautifulSoup(response.content, 'html.parser')

# remove unnecessory elements of HTML tree
for s in soup(['style', 'script', '[document]', 'head', 'title']):
  s.extract()

#now get the text
text = soup.get_text()
text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearchSAP\n\n\n\n\nSearch the TechTarget Network\n\n\n\n\nSign-up now. Start my free, unlimited access.\n\nLogin\nRegister\n\n\n\n\nTechtarget Network\nNews\nFeatures\nTips\nWebinars\n\nMore Content\n\n\nAnswers\nDefinitions\nEssential Guides\nOpinions\nPhoto Stories\nPodcasts\nQuizzes\nTutorials\n\nSponsored Communities\n\n\n\n\n\n\n\n\n\n\n\nSearchSAP\n\n\n\n\n\nTopic  \n\t\t\t\t\t\t\t\tERP Software\n  \n\n\n\n\n Data Management\n SAP Developer Tools\n HANA\n Infrastructure & Cloud\nAll Topics\n\n\n\n\n\nFollow:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nphive2015 - stock.adobe.com\n\n\n\n\n\nNews\n\n\nUnilever pursues supply chain sustainability with blockchain\n\n\n\nUnilever deploys blockchain-enabled GreenToken by SAP to help ensure the palm oil used in its products comes from responsible sources and doesn\'t contribute to rainforest loss.\n\n\n\n\n\n\nShare this item with your network:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBy\n\n\nJim O\'Donnell,\nNews Writer\n\n\n\n\tPublished: 30 Mar 2022\n\n\n \nUnilever, a consumer products giant, is hoping to improve its supply chain sustainability practices by implementing GreenToken by SAP, a startup that provides blockchain-based technology.\n\n\n\n\n\n\n\n\nUnilever\'s focus for the technology is palm oil, which is derived from the fruit of the oil palm tree and is used in thousands of non-food consumer products, including soaps and shampoos. However, sustainability issues, most notably deforestation, are on the rise connected to the production of palm oil and its supply chain after the first mile.\n\nAndrew Wilcox\n\nMost of Unilever\'s oil palm plantations are located in the Leuser rainforest in the Aceh province of Indonesia, one of two major areas of palm oil production. The rapid expansion of the palm oil industry has resulted in poor production standards and accelerated deforestation, according to Andrew Wilcox, senior manager of sustainable sourcing and digital programs at Unilever. The expansion of oil palm plantations has further led to land conflicts between plantation companies and local communities.\nUnilever, which has been seeking ways to create a sustainable forest footprint, is now adding GreenToken\'s blockchain technology to provide transparency and traceability of its palm oil supply chain, improving the sustainability of palm oil production, according to the company. Unilever has used technology such as satellite imaging and AI to monitor deforestation and land conversion, while the GreenToken project is a new effort to specifically address supply chain issues.\nLast fall, Unilever published a report on the environmental issues facing the palm oil industry and how it\'s addressing those issues. In it, the company stated that about 128,700 hectares (ha) of forests have been destroyed for palm oil expansion between 2016 and 2020. Further, 2,020,700 ha of forest and 201,700 ha of peat in Aceh are at risk of potential future conversion and clearing into oil palm.\nUnilever, along with other consumer goods companies like PepsiCo, Procter & Gamble, Ferrero, Nissin Foods and Mars, face increased public pressure from non-governmental organizations such as the Rainforest Action Network (RAN) to disclose their rainforest footprints.\nCompanies like Unilever are also coming under increased scrutiny from governments, most notably by European countries that have adopted regulations. Likewise, the U.S. is also increasing its focus on sustainability, with proposed Securities and Exchange Commission rules that \xa0would require publicly traded companies to report on climate-related risks such as weather variability severe enough to affect business operations and financial conditions.\n\n\n\n\n\n\n\nComplex supply chain and controversy\nSupply chains for palm oil are long and complex, and the material can go through dozens of transformations as it moves from company to company from the time ...

# %% [markdown]
# ## 2 - Tokenizing text
#
# ### TextBlob
#
# * https://textblob.readthedocs.io/en/latest/
# * Object-oriented NLP text-processing library that is built on the NLTK and pattern NLP libraries
# * TextBlob is a Python library for processing textual data.
# * One of the tasks **TextBlob** can perform is:
#     * Tokenization—splitting text into pieces called tokens, which are meaningful units, such as words and numbers

# %%
# !pip install -U textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 15.0 MB/s
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (7.1.2)
# Installing collected packages: textblob
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# Successfully installed textblob-0.17.1

# %%
from textblob import TextBlob
import nltk #NLTK, or Natural Language Toolkit, is a Python package that used for NLP
nltk.download('punkt') #Punkt Sentence Tokenizer - This tokenizer divides a text into a list of sentences
  
blob = TextBlob(text)

tokens = blob.words
tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WordList(['SearchSAP', 'Search', 'the', 'TechTarget', 'Network', 'Sign-up', 'now', 'Start', 'my', 'free', 'unlimited', 'access', 'Login', 'Register', 'Techtarget', 'Network', 'News', 'Features', 'Tips', 'Webinars', 'More', 'Content', 'Answers', 'Definitions', 'Essential', 'Guides', 'Opinions', 'Photo', 'Stories', 'Podcasts', 'Quizzes', 'Tutorials', 'Sponsored', 'Communities', 'SearchSAP', 'Topic', 'ERP', 'Software', 'Data', 'Management', 'SAP', 'Developer', 'Tools', 'HANA', 'Infrastructure', 'Cloud', 'All', 'Topics', 'Follow', 'phive2015', 'stock.adobe.com', 'News', 'Unilever', 'pursues', 'supply', 'chain', 'sustainability', 'with', 'blockchain', 'Unilever', 'deploys', 'blockchain-enabled', 'GreenToken', 'by', 'SAP', 'to', 'help', 'ensure', 'the', 'palm', 'oil', 'used', 'in', 'its', 'products', 'comes', 'from', 'responsible', 'sources', 'and', 'does', "n't", 'contribute', 'to', 'rainforest', 'loss', 'Share', 'this', 'item', 'with', 'your', 'network', 'By', 'Jim', "O'Donnell", 'News', 'Writer', 'Published', '30', 'Mar', '2022', 'Unilever', 'a', 'consumer', 'products', 'giant', 'is', 'hoping', 'to', 'improve', 'its', 'supply', 'chain', 'sustainability', 'practices', 'by', 'implementing', 'GreenToken', 'by', 'SAP', 'a', 'startup', 'that', 'provides', 'blockchain-based', 'technology', 'Unilever', "'s", 'focus', 'for', 'the', 'technology', 'is', 'palm', 'oil', 'which', 'is', 'derived', 'from', 'the', 'fruit', 'of', 'the', 'oil', 'palm', 'tree', 'and', 'is', 'used', 'in', 'thousands', 'of', 'non-food', 'consumer', 'products', 'including', 'soaps', 'and', 'shampoos', 'However', 'sustainability', 'issues', 'most', 'notably', 'deforestation', 'are', 'on', 'the', 'rise', 'connected', 'to', 'the', 'production', 'of', 'palm', 'oil', 'and', 'its', 'supply', 'chain', 'after', 'the', 'first', 'mile', 'Andrew', 'Wilcox', 'Most', 'of', 'Unilever', "'s", 'oil', 'palm', 'plantations', 'are', 'located', 'in', 'the', 'Leuser', 'rainforest', 'in', 'the', 'Aceh', 'province', 'of', 'Indonesia', 'one', 'of', 'two', 'major', 'areas', 'of', 'palm', 'oil', 'production', 'The', 'rapid', 'expansion', 'of', 'the', 'palm', 'oil', 'industry', 'has', 'resulted', 'in', 'poor', 'production', 'standards', 'and', 'accelerated', 'deforestation', 'according', 'to', 'Andrew', 'Wilcox', 'senior', 'manager', 'of', 'sustainable', 'sourcing', 'and', 'digital', 'programs', 'at', 'Unilever', 'The', 'expansion', 'of', 'oil', 'palm', 'plantations', 'has', 'further', 'led', 'to', 'land', 'conflicts', 'between', 'plantation', 'companies', 'and', 'local', 'communities', 'Unilever', 'which', 'has', 'been', 'seeking', 'ways', 'to', 'create', 'a', 'sustainable', 'forest', 'footprint', 'is', 'now', 'adding', 'GreenToken', "'s", 'blockchain', 'technology', 'to', 'provide', 'transparency', 'and', 'traceability', 'of', 'its', 'palm', 'oil', 'supply', 'chain', 'improving', 'the', 'sustainability', 'of', 'palm', 'oil', 'production', 'according', 'to', 'the', 'company', 'Unilever', 'has', 'used', 'technology', 'such', 'as', 'satellite', 'imaging', 'and', 'AI', 'to', 'monitor', 'deforestation', 'and', 'land', 'conversion', 'while', 'the', 'GreenToken', 'project', 'is', 'a', 'new', 'effort', 'to', 'specifically', 'address', 'supply', 'chain', 'issues', 'Last', 'fall', 'Unilever', 'published', 'a', 'report', 'on', 'the', 'environmental', 'issues', 'facing', 'the', 'palm', 'oil', 'industry', 'and', 'how', 'it', "'s", 'addressing', 'those', 'issues', 'In', 'it', 'the', 'company', 'stated', 'that', 'about', '128,700', 'hectares', 'ha', 'of', 'forests', 'have', 'been', 'destroyed', 'for', 'palm', 'oil', 'expansion', 'between', '2016', 'and', '2020', 'Further', '2,020,700', 'ha', 'of', 'forest', 'and', '201,700', 'ha', 'of', 'peat', 'in', 'Aceh', 'are', 'at', 'risk', 'of', 'potential', 'future', 'conversion', 'and', 'clearing', 'into', 'oil', 'palm', 'Unilever', 'along', 'with', 'other', 'consumer', 'goods', 'companies', 'like', 'PepsiCo', 'Procter', 'Gamble', 'Ferrero', 'Nissin', 'Foods', 'and' ...

# %% [markdown]
# ### Another approach to tokenize text - Tokenize using NLTK Regular-Expression Tokenizers
#
# https://www.nltk.org/api/nltk.tokenize.regexp.html
#
# https://www.nltk.org/_modules/nltk/tokenize/regexp.html

# %%
#Alternative

# Creating a tokenizer
tokenizer = nltk.tokenize.RegexpTokenizer('\w+')

# Tokenizing the text
tokensReg = tokenizer.tokenize(text)
tokensReg
# Out:
# ['SearchSAP',
#  'Search',
#  'the',
#  'TechTarget',
#  'Network',
#  'Sign',
#  'up',
#  'now',
#  'Start',
#  'my',
#  'free',
#  'unlimited',
#  'access',
#  'Login',
#  'Register',
#  'Techtarget',
#  'Network',
#  'News',
#  'Features',
#  'Tips',
#  'Webinars',
#  'More',
#  'Content',
#  'Answers',
#  'Definitions',
#  'Essential',
#  'Guides',
#  'Opinions',
#  'Photo',
#  'Stories',
#  'Podcasts',
#  'Quizzes',
#  'Tutorials',
#  'Sponsored',
#  'Communities',
#  'SearchSAP',
#  'Topic',
#  'ERP',
#  'Software',
#  'Data',
#  'Management',
#  'SAP',
#  'Developer',
#  'Tools',
#  'HANA',
#  'Infrastructure',
#  'Cloud',
#  'All',
#  'Topics',
#  'Follow',
#  'phive2015',
#  'stock',
#  'adobe',
#  'com',
#  'News',
#  'Unilever',
#  'pursues',
#  'supply',
#  'chain',
#  'sustainability',
#  'with',
#  'blockchain',
#  'Unilever',
#  'deploys',
#  'blockchain',
#  'enabled',
#  'GreenToken',
#  'by',
#  'SAP',
#  'to',
#  'help',
#  'ensure',
#  'the',
#  'palm',
#  'oil',
#  'used',
#  'in',
#  'its',
#  'products',
#  'comes',
#  'from',
#  'responsible',
#  'sources',
#  'and',
#  'doesn',
#  't',
#  'contribute',
#  'to',
#  'rainforest',
#  'loss',
#  'Share',
#  'this',
#  'item',
#  'with',
#  'your',
#  'network',
#  'By',
#  'Jim',
#  'O',
#  'Donnell',
#  'News',
#  'Writer',
#  'Published',
#  '30',
#  'Mar',
#  '2022',
#  'Unilever',
#  'a',
#  'consumer',
#  'products',
#  'giant',
#  'is',
#  'hoping',
#  'to',
#  'improve',
#  'its',
#  'supply',
#  'chain',
#  'sustainability',
#  'practices',
#  'by',
#  'implementing',
#  'GreenToken',
#  'by',
#  'SAP',
#  'a',
#  'startup',
#  'that',
#  'provides',
#  'blockchain',
#  'based',
#  'technology',
#  'Unilever',
#  's',
#  'focus',
#  'for',
#  'the',
#  'technology',
#  'is',
#  'palm',
#  'oil',
#  'which',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'fruit',
#  'of',
#  'the',
#  'oil',
#  'palm',
#  'tree',
#  'and',
#  'is',
#  'used',
#  'in',
#  'thousands',
#  'of',
#  'non',
#  'food',
#  'consumer',
#  'products',
#  'including',
#  'soaps',
#  'and',
#  'shampoos',
#  'However',
#  'sustainability',
#  'issues',
#  'most',
#  'notably',
#  'deforestation',
#  'are',
#  'on',
#  'the',
#  'rise',
#  'connected',
#  'to',
#  'the',
#  'production',
#  'of',
#  'palm',
#  'oil',
#  'and',
#  'its',
#  'supply',
#  'chain',
#  'after',
#  'the',
#  'first',
#  'mile',
#  'Andrew',
#  'Wilcox',
#  'Most',
#  'of',
#  'Unilever',
#  's',
#  'oil',
#  'palm',
#  'plantations',
#  'are',
#  'located',
#  'in',
#  'the',
#  'Leuser',
#  'rainforest',
#  'in',
#  'the',
#  'Aceh',
#  'province',
#  'of',
#  'Indonesia',
#  'one',
#  'of',
#  'two',
#  'major',
#  'areas',
#  'of',
#  'palm',
#  'oil',
#  'production',
#  'The',
#  'rapid',
#  'expansion',
#  'of',
#  'the',
#  'palm',
#  'oil',
#  'industry',
#  'has',
#  'resulted',
#  'in',
#  'poor',
#  'production',
#  'standards',
#  'and',
#  'accelerated',
#  'deforestation',
#  'according',
#  'to',
#  'Andrew',
#  'Wilcox',
#  'senior',
#  'manager',
#  'of',
#  'sustainable',
#  'sourcing',
#  'and',
#  'digital',
#  'programs',
#  'at',
#  'Unilever',
#  'The',
#  'expansion',
#  'of',
#  'oil',
#  'palm',
#  'plantations',
#  'has',
#  'further',
#  'led',
#  'to',
#  'land',
#  'conflicts',
#  'between',
#  'plantation',
#  'companies',
#  'and',
#  'local',
#  'communities',
#  'Unilever',
#  'which',
#  'has',
#  'been',
#  'seeking',
#  'ways',
#  'to',
#  'create',
#  'a',
#  'sustainable',
#  'forest',
#  'footprint',
#  'is',
#  'now',
#  'adding',
#  'GreenToken',
#  's',
#  'blockchain',
#  'technology',
#  'to',
#  'provide',
#  'transparency',
#  'and',
#  'traceability',
#  'of',
#  'its',
#  'palm',
#  'oil',
#  'supply',
#  'chain',
#  'improving',
#  'the',
#  'sustainability',
#  'of',
#  'palm',
#  'oil',
#  'production',
#  'according',
#  'to',
#  'the',
#  'company',
#  'Unilever',
#  'has',
#  'used',
#  'technology',
#  'such',
#  'as',
#  'satellite',
#  'imaging',
#  'and',
#  'AI',
#  'to',
#  'monitor',
#  'deforestation',
#  'and',
#  'land',
#  'conversion',
#  'while',
#  'the',
#  'GreenToken',
#  'project',
#  'is',
#  'a',
#  'new',
#  'effort',
#  'to',
#  'specifically',
#  'address',
#  'supply',
#  'chain',
#  'issues',
#  'Last',
#  'fall',
#  'Unilever',
#  'published',
#  'a',
#  'report',
#  'on',
#  'the',
#  'environmental',
#  'issues',
#  'facing',
#  'the',
#  'palm',
#  'oil',
#  'industry',
#  'and',
#  'how',
#  'it',
#  's',
#  'addressing',
#  'those',
#  'issues',
#  'In',
#  'it',
#  'the',
#  'company',
#  'stated',
#  'that',
#  'about',
#  '128',
#  '700',
#  'hectares',
#  'ha',
#  'of',
#  'forests',
#  'have',
#  'been',
#  'destroyed',
#  'for',
#  'palm',
#  'oil',
#  'expansion',
#  'between',
#  '2016',
#  'and',
#  '2020',
#  'Further',
#  '2',
#  '020',
#  '700',
#  'ha',
#  'of',
#  'forest',
#  'and',
#  '201',
#  '700',
#  'ha',
#  'of',
#  'peat',
#  'in',
#  'Aceh',
#  'are',
#  'at',
#  'risk',
#  'of',
#  'potential',
#  'future',
#  'conversion',
#  'and',
#  'clearing',
#  'into',
#  'oil',
#  'palm',
#  'Unilever',
#  'along',
#  'with',
#  'other',
#  'consumer',
#  'goods',
#  'companies',
#  'like',
#  'PepsiCo',
#  'Procter',
#  'Gamble',
#  'Ferrero',
#  'Nissin',
#  'Foods',
#  'and',
#  'Mars',
#  'face',
#  'increased',
#  'public',
#  'pressure',
#  'from',
#  'non',
#  'governmental',
#  'organizations',
#  'such',
#  'as',
#  'the',
#  'Rainforest',
#  'Action',
#  'Network',
#  'RAN',
#  'to',
#  'disclose',
#  'their',
#  'rainforest',
#  'footprints',
#  'Companies',
#  'like',
#  'Unilever',
#  'are',
#  'also',
#  'coming',
#  'under',
#  'increased',
#  'scrutiny',
#  'from',
#  'governments',
#  'most',
#  'notably',
#  'by',
#  'European',
#  'countries',
#  'that',
#  'have',
#  'adopted',
#  'regulations',
#  'Likewise',
#  'the',
#  'U',
#  'S',
#  'is',
#  'also',
#  'increasing',
#  'its',
#  'focus',
#  'on',
#  'sustainability',
#  'with',
#  'proposed',
#  'Securities',
#  'and',
#  'Exchange',
#  'Commission',
#  'rules',
#  'that',
#  'would',
#  'require',
#  'publicly',
#  'traded',
#  'companies',
#  'to',
#  'report',
#  'on',
#  'climate',
#  'related',
#  'risks',
#  'such',
#  'as',
#  'weather',
#  'variability',
#  'severe',
#  'enough',
#  'to',
#  'affect',
#  'business',
#  'operations',
#  'and',
#  'financial',
#  'conditions',
#  'Complex',
#  'supply',
#  'chain',
#  'and',
#  'controversy',
#  'Supply',
#  'chains',
#  'for',
#  'palm',
#  'oil',
#  'are',
#  'long',
#  'and',
#  'complex',
#  'and',
#  'the',
#  'material',
#  'can',
#  'go',
#  'through',
#  'dozens',
#  'of',
#  'transformations',
#  'as',
#  'it',
#  'moves',
#  'from',
#  'company',
#  'to',
#  'company',
#  'from',
#  'the',
#  'time',
#  'it',
#  's',
#  'harvested',
#  'until',
#  'it',
#  'ends',
#  'up',
#  'as',
#  'soap',
#  'or',
#  'shampoo',
#  'Wilcox',
#  'said',
#  'Companies',
#  'want',
#  'to',
#  'make',
#  'sure',
#  'that',
#  'the',
#  'palm',
#  'oil',
#  'they',
#  're',
#  'sourcing',
#  'comes',
#  'from',
#  'responsible',
#  'sources',
#  'such',
#  'as',
#  'plantations',
#  'that',
#  'don',
#  't',
#  'contribute',
#  'to',
#  'deforestation',
#  'he',
#  'said',
#  'Palm',
#  'fruit',
#  'coming',
#  'from',
#  'a',
#  'sustainably',
#  'maintained',
#  'planation',
#  'looks',
#  'the',
#  'same',
#  'and',
#  'has',
#  'the',
#  'same',
#  'chemical',
#  'properties',
#  'as',
#  'fruit',
#  'from',
#  'deforested',
#  'lands',
#  'but',
#  'certifications',
#  'from',
#  'organizations',
#  'like',
#  'the',
#  'Roundtable',
#  'on',
#  'Sustainable',
#  'Palm',
#  'Oil',
#  'and',
#  'the',
#  'Palm',
#  'Oil',
#  'Innovation',
#  'Group',
#  'assure',
#  'companies',
#  'that',
#  'the',
#  'palm',
#  'oil',
#  'comes',
#  'from',
#  'a',
#  'responsible',
#  'source',
#  'Indeed',
#  'Unilever',
#  'faced',
#  'pressure',
#  'from',
#  'RAN',
#  'after',
#  'publishing',
#  'its',
#  '2021',
#  'forest',
#  'footprint',
#  'report',
#  'RAN',
#  'has',
#  'exposed',
#  'Unilever',
#  's',
#  'connections',
#  'to',
#  'rogue',
#  'actors',
#  'destroying',
#  'rainforests',
#  'in',
#  'the',
#  'Leuser',
#  'ecosystem',
#  'for',
#  'over',
#  'five',
#  'years',
#  'Maggie',
#  'Martin',
#  'senior',
#  'forest',
#  'campaigner',
#  'at',
#  'RAN',
#  'said',
#  'in',
#  'a',
#  'statement',
#  'following',
#  'Unilever',
#  's',
#  '2021',
#  'forest',
#  'footprint',
#  'report',
#  'Unilever',
#  'has',
#  'a',
#  'responsibility',
#  'to',
#  'address',
#  'the',
#  'harm',
#  'caused',
#  'to',
#  'communities',
#  'forests',
#  'and',
#  'the',
#  'climate',
#  'through',
#  'its',
#  'decade',
#  'long',
#  'sourcing',
#  'of',
#  'conflict',
#  'palm',
#  'oil',
#  'from',
#  'the',
#  'region',
#  'and',
#  'prevent',
#  'further',
#  'deforestation',
#  'and',
#  'human',
#  'rights',
#  'violations',
#  'across',
#  'Aceh',
#  'Unilever',
#  'is',
#  'aware',
#  'of',
#  'the',
#  'need',
#  'to',
#  'tackle',
#  'these',
#  'and',
#  'other',
#  'issues',
#  'associated',
#  'with',
#  'palm',
#  'oil',
#  'such',
#  'as',
#  'climate',
#  'change',
#  'biodiversity',
#  'loss',
#  'and',
#  'human',
#  'rights',
#  'issues',
#  'Wilcox',
#  'said',
#  'That',
#  's',
#  'why',
#  'we',
#  'have',
#  'made',
#  'a',
#  'commitment',
#  'to',
#  'sustainably',
#  'source',
#  'all',
#  'the',
#  'palm',
#  'oil',
#  'we',
#  'use',
#  'in',
#  'our',
#  'products',
#  'One',
#  'aspect',
#  'of',
#  'its',
#  'strategy',
#  'to',
#  'meet',
#  'that',
#  'commitment',
#  'is',
#  'using',
#  'technology',
#  'such',
#  'as',
#  'GreenToken',
#  'which',
#  'is',
#  'helping',
#  'Unilever',
#  'track',
#  'verify',
#  'and',
#  'report',
#  'in',
#  'near',
#  'real',
#  'time',
#  'the',
#  'origins',
#  'and',
#  'journey',
#  'that',
#  'palm',
#  'oil',
#  'takes',
#  'through',
#  'the',
#  'long',
#  'and',
#  'complex',
#  'supply',
#  'chain',
#  'he',
#  'said',
#  'Nitin',
#  'Jain',
#  'GreenToken',
#  'is',
#  'a',
#  'blockchain',
#  'based',
#  'supply',
#  'chain',
#  'traceability',
#  'and',
#  'chain',
#  'of',
#  'custody',
#  'application',
#  'that',
#  'allows',
#  'companies',
#  'to',
#  'record',
#  'and',
#  'track',
#  'facts',
#  'about',
#  'the',
#  'raw',
#  'materials',
#  'they',
#  'use',
#  'in',
#  'products',
#  'according',
#  'to',
#  'Nitin',
#  'Jain',
#  'co',
#  'founder',
#  'and',
#  'general',
#  'manager',
#  'of',
#  'the',
#  'startup',
#  'This',
#  'can',
#  'include',
#  'information',
#  'like',
#  'where',
#  'raw',
#  'materials',
#  'originate',
#  'specific',
#  'production',
#  'attributes',
#  'and',
#  'certifications',
#  'GreenToken',
#  'which',
#  'companies',
#  'can',
#  'access',
#  'through',
#  'a',
#  'SaaS',
#  'interface',
#  'dashboard',
#  'provides',
#  'the',
#  'ability',
#  'for',
#  'producers',
#  'to',
#  'create',
#  'a',
#  'digital',
#  'token',
#  'of',
#  'physical',
#  'goods',
#  'that',
#  'can',
#  'include',
#  'multiple',
#  'attributes',
#  'such',
#  'as',
#  'the',
#  'original',
#  'plantation',
#  'and',
#  'any',
#  'certifications',
#  'It',
#  'then',
#  'uses',
#  'blockchain',
#  'technology',
#  'to',
#  'establish',
#  'a',
#  'chain',
#  'of',
#  'custody',
#  'for',
#  'the',
#  'tokens',
#  'that',
#  'cannot',
#  'be',
#  'altered',
#  'as',
#  'the',
#  'materials',
#  'move',
#  'through',
#  'the',
#  'supply',
#  'chain',
#  'Jain',
#  'said',
#  'You',
#  'can',
#  'have',
#  'facts',
#  'about',
#  'commodity',
#  'that',
#  'say',
#  'it',
#  's',
#  'coming',
#  'from',
#  'a',
#  'mature',
#  'plantation',
#  'with',
#  'no',
#  'deforestation',
#  'he',
#  'said',
#  'With',
#  'blockchain',
#  'any',
#  'entity',
#  'can',
#  'only',
#  'sell',
#  'so',
#  'much',
#  'of',
#  'certified',
#  'content',
#  'that',
#  'they',
#  'are',
#  'receiving',
#  'and',
#  'there',
#  'cannot',
#  'be',
#  'any',
#  'double',
#  'spending',
#  'of',
#  'the',
#  'certificates',
#  'or',
#  'tokens',
#  'A',
#  'use',
#  'case',
#  'for',
#  'supply',
#  'chain',
#  'transparency',
#  'Unilever',
#  'has',
#  'been',
#  'using',
#  'technology',
#  'to',
#  'further',
#  'sustainability',
#  'goals',
#  ...]

# %% [markdown]
# ## 3 - Remove common words (`stopwords`) from text

# %% [markdown]
# ### Getting the English stop words from nltk
#
#  `Stopwords` are common words which provide little to no value to the meaning of the text.

# %%
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
## Remove stop words in the text ##
filtered_text = []

for w in tokens:
    if w not in stop_words:
        filtered_text.append(w)
        
filtered_text
# Out:
# ['SearchSAP',
#  'Search',
#  'TechTarget',
#  'Network',
#  'Sign-up',
#  'Start',
#  'free',
#  'unlimited',
#  'access',
#  'Login',
#  'Register',
#  'Techtarget',
#  'Network',
#  'News',
#  'Features',
#  'Tips',
#  'Webinars',
#  'More',
#  'Content',
#  'Answers',
#  'Definitions',
#  'Essential',
#  'Guides',
#  'Opinions',
#  'Photo',
#  'Stories',
#  'Podcasts',
#  'Quizzes',
#  'Tutorials',
#  'Sponsored',
#  'Communities',
#  'SearchSAP',
#  'Topic',
#  'ERP',
#  'Software',
#  'Data',
#  'Management',
#  'SAP',
#  'Developer',
#  'Tools',
#  'HANA',
#  'Infrastructure',
#  'Cloud',
#  'All',
#  'Topics',
#  'Follow',
#  'phive2015',
#  'stock.adobe.com',
#  'News',
#  'Unilever',
#  'pursues',
#  'supply',
#  'chain',
#  'sustainability',
#  'blockchain',
#  'Unilever',
#  'deploys',
#  'blockchain-enabled',
#  'GreenToken',
#  'SAP',
#  'help',
#  'ensure',
#  'palm',
#  'oil',
#  'used',
#  'products',
#  'comes',
#  'responsible',
#  'sources',
#  "n't",
#  'contribute',
#  'rainforest',
#  'loss',
#  'Share',
#  'item',
#  'network',
#  'By',
#  'Jim',
#  "O'Donnell",
#  'News',
#  'Writer',
#  'Published',
#  '30',
#  'Mar',
#  '2022',
#  'Unilever',
#  'consumer',
#  'products',
#  'giant',
#  'hoping',
#  'improve',
#  'supply',
#  'chain',
#  'sustainability',
#  'practices',
#  'implementing',
#  'GreenToken',
#  'SAP',
#  'startup',
#  'provides',
#  'blockchain-based',
#  'technology',
#  'Unilever',
#  "'s",
#  'focus',
#  'technology',
#  'palm',
#  'oil',
#  'derived',
#  'fruit',
#  'oil',
#  'palm',
#  'tree',
#  'used',
#  'thousands',
#  'non-food',
#  'consumer',
#  'products',
#  'including',
#  'soaps',
#  'shampoos',
#  'However',
#  'sustainability',
#  'issues',
#  'notably',
#  'deforestation',
#  'rise',
#  'connected',
#  'production',
#  'palm',
#  'oil',
#  'supply',
#  'chain',
#  'first',
#  'mile',
#  'Andrew',
#  'Wilcox',
#  'Most',
#  'Unilever',
#  "'s",
#  'oil',
#  'palm',
#  'plantations',
#  'located',
#  'Leuser',
#  'rainforest',
#  'Aceh',
#  'province',
#  'Indonesia',
#  'one',
#  'two',
#  'major',
#  'areas',
#  'palm',
#  'oil',
#  'production',
#  'The',
#  'rapid',
#  'expansion',
#  'palm',
#  'oil',
#  'industry',
#  'resulted',
#  'poor',
#  'production',
#  'standards',
#  'accelerated',
#  'deforestation',
#  'according',
#  'Andrew',
#  'Wilcox',
#  'senior',
#  'manager',
#  'sustainable',
#  'sourcing',
#  'digital',
#  'programs',
#  'Unilever',
#  'The',
#  'expansion',
#  'oil',
#  'palm',
#  'plantations',
#  'led',
#  'land',
#  'conflicts',
#  'plantation',
#  'companies',
#  'local',
#  'communities',
#  'Unilever',
#  'seeking',
#  'ways',
#  'create',
#  'sustainable',
#  'forest',
#  'footprint',
#  'adding',
#  'GreenToken',
#  "'s",
#  'blockchain',
#  'technology',
#  'provide',
#  'transparency',
#  'traceability',
#  'palm',
#  'oil',
#  'supply',
#  'chain',
#  'improving',
#  'sustainability',
#  'palm',
#  'oil',
#  'production',
#  'according',
#  'company',
#  'Unilever',
#  'used',
#  'technology',
#  'satellite',
#  'imaging',
#  'AI',
#  'monitor',
#  'deforestation',
#  'land',
#  'conversion',
#  'GreenToken',
#  'project',
#  'new',
#  'effort',
#  'specifically',
#  'address',
#  'supply',
#  'chain',
#  'issues',
#  'Last',
#  'fall',
#  'Unilever',
#  'published',
#  'report',
#  'environmental',
#  'issues',
#  'facing',
#  'palm',
#  'oil',
#  'industry',
#  "'s",
#  'addressing',
#  'issues',
#  'In',
#  'company',
#  'stated',
#  '128,700',
#  'hectares',
#  'ha',
#  'forests',
#  'destroyed',
#  'palm',
#  'oil',
#  'expansion',
#  '2016',
#  '2020',
#  'Further',
#  '2,020,700',
#  'ha',
#  'forest',
#  '201,700',
#  'ha',
#  'peat',
#  'Aceh',
#  'risk',
#  'potential',
#  'future',
#  'conversion',
#  'clearing',
#  'oil',
#  'palm',
#  'Unilever',
#  'along',
#  'consumer',
#  'goods',
#  'companies',
#  'like',
#  'PepsiCo',
#  'Procter',
#  'Gamble',
#  'Ferrero',
#  'Nissin',
#  'Foods',
#  'Mars',
#  'face',
#  'increased',
#  'public',
#  'pressure',
#  'non-governmental',
#  'organizations',
#  'Rainforest',
#  'Action',
#  'Network',
#  'RAN',
#  'disclose',
#  'rainforest',
#  'footprints',
#  'Companies',
#  'like',
#  'Unilever',
#  'also',
#  'coming',
#  'increased',
#  'scrutiny',
#  'governments',
#  'notably',
#  'European',
#  'countries',
#  'adopted',
#  'regulations',
#  'Likewise',
#  'U.S',
#  'also',
#  'increasing',
#  'focus',
#  'sustainability',
#  'proposed',
#  'Securities',
#  'Exchange',
#  'Commission',
#  'rules',
#  'would',
#  'require',
#  'publicly',
#  'traded',
#  'companies',
#  'report',
#  'climate-related',
#  'risks',
#  'weather',
#  'variability',
#  'severe',
#  'enough',
#  'affect',
#  'business',
#  'operations',
#  'financial',
#  'conditions',
#  'Complex',
#  'supply',
#  'chain',
#  'controversy',
#  'Supply',
#  'chains',
#  'palm',
#  'oil',
#  'long',
#  'complex',
#  'material',
#  'go',
#  'dozens',
#  'transformations',
#  'moves',
#  'company',
#  'company',
#  'time',
#  "'s",
#  'harvested',
#  'ends',
#  'soap',
#  'shampoo',
#  'Wilcox',
#  'said',
#  'Companies',
#  'want',
#  'make',
#  'sure',
#  'palm',
#  'oil',
#  "'re",
#  'sourcing',
#  'comes',
#  'responsible',
#  'sources',
#  'plantations',
#  "n't",
#  'contribute',
#  'deforestation',
#  'said',
#  'Palm',
#  'fruit',
#  'coming',
#  'sustainably',
#  'maintained',
#  'planation',
#  'looks',
#  'chemical',
#  'properties',
#  'fruit',
#  'deforested',
#  'lands',
#  'certifications',
#  'organizations',
#  'like',
#  'Roundtable',
#  'Sustainable',
#  'Palm',
#  'Oil',
#  'Palm',
#  'Oil',
#  'Innovation',
#  'Group',
#  'assure',
#  'companies',
#  'palm',
#  'oil',
#  'comes',
#  'responsible',
#  'source',
#  'Indeed',
#  'Unilever',
#  'faced',
#  'pressure',
#  'RAN',
#  'publishing',
#  '2021',
#  'forest',
#  'footprint',
#  'report',
#  'RAN',
#  'exposed',
#  'Unilever',
#  "'s",
#  'connections',
#  'rogue',
#  'actors',
#  'destroying',
#  'rainforests',
#  'Leuser',
#  'ecosystem',
#  'five',
#  'years',
#  'Maggie',
#  'Martin',
#  'senior',
#  'forest',
#  'campaigner',
#  'RAN',
#  'said',
#  'statement',
#  'following',
#  'Unilever',
#  "'s",
#  '2021',
#  'forest',
#  'footprint',
#  'report',
#  'Unilever',
#  'responsibility',
#  'address',
#  'harm',
#  'caused',
#  'communities',
#  'forests',
#  'climate',
#  'decade-long',
#  'sourcing',
#  'conflict',
#  'palm',
#  'oil',
#  'region',
#  'prevent',
#  'deforestation',
#  'human',
#  'rights',
#  'violations',
#  'across',
#  'Aceh',
#  'Unilever',
#  'aware',
#  'need',
#  'tackle',
#  'issues',
#  'associated',
#  'palm',
#  'oil',
#  'climate',
#  'change',
#  'biodiversity',
#  'loss',
#  'human',
#  'rights',
#  'issues',
#  'Wilcox',
#  'said',
#  'That',
#  "'s",
#  'made',
#  'commitment',
#  'sustainably',
#  'source',
#  'palm',
#  'oil',
#  'use',
#  'products',
#  'One',
#  'aspect',
#  'strategy',
#  'meet',
#  'commitment',
#  'using',
#  'technology',
#  'GreenToken',
#  'helping',
#  'Unilever',
#  'track',
#  'verify',
#  'report',
#  'near-real-time',
#  'origins',
#  'journey',
#  'palm',
#  'oil',
#  'takes',
#  'long',
#  'complex',
#  'supply',
#  'chain',
#  'said',
#  'Nitin',
#  'Jain',
#  'GreenToken',
#  'blockchain-based',
#  'supply',
#  'chain',
#  'traceability',
#  'chain-of-custody',
#  'application',
#  'allows',
#  'companies',
#  'record',
#  'track',
#  'facts',
#  'raw',
#  'materials',
#  'use',
#  'products',
#  'according',
#  'Nitin',
#  'Jain',
#  'co-founder',
#  'general',
#  'manager',
#  'startup',
#  'This',
#  'include',
#  'information',
#  'like',
#  'raw',
#  'materials',
#  'originate',
#  'specific',
#  'production',
#  'attributes',
#  'certifications',
#  'GreenToken',
#  'companies',
#  'access',
#  'SaaS',
#  'interface',
#  'dashboard',
#  'provides',
#  'ability',
#  'producers',
#  'create',
#  'digital',
#  'token',
#  'physical',
#  'goods',
#  'include',
#  'multiple',
#  'attributes',
#  'original',
#  'plantation',
#  'certifications',
#  'It',
#  'uses',
#  'blockchain',
#  'technology',
#  'establish',
#  'chain',
#  'custody',
#  'tokens',
#  'altered',
#  'materials',
#  'move',
#  'supply',
#  'chain',
#  'Jain',
#  'said',
#  'You',
#  'facts',
#  'commodity',
#  'say',
#  "'s",
#  'coming',
#  'mature',
#  'plantation',
#  'deforestation',
#  'said',
#  'With',
#  'blockchain',
#  'entity',
#  'sell',
#  'much',
#  'certified',
#  'content',
#  'receiving',
#  'double',
#  'spending',
#  'certificates',
#  'tokens',
#  'A',
#  'use',
#  'case',
#  'supply',
#  'chain',
#  'transparency',
#  'Unilever',
#  'using',
#  'technology',
#  'sustainability',
#  'goals',
#  'satellite',
#  'images',
#  'track',
#  'deforestation',
#  'supply',
#  'chain',
#  'said',
#  'Marta',
#  'Muñoz',
#  'technology',
#  'sustainability',
#  'social',
#  'impact',
#  'practice',
#  'lead',
#  'IDC',
#  'Europe',
#  'Marta',
#  'Muñoz',
#  'Blockchain',
#  'good',
#  'option',
#  'supply',
#  'chain',
#  'transparency',
#  'Muñoz',
#  'said',
#  'used',
#  'successfully',
#  'areas',
#  'like',
#  'automotive',
#  'computer',
#  'manufacturing',
#  'trace',
#  'origin',
#  'metals',
#  'used',
#  'avoid',
#  'conflict',
#  'minerals',
#  'Supply',
#  'chain',
#  'transparency',
#  'becoming',
#  'increasingly',
#  'important',
#  'area',
#  'organizations',
#  'around',
#  'world',
#  'particularly',
#  'relevant',
#  'Europe',
#  'Muñoz',
#  'said',
#  'For',
#  'example',
#  'Germany',
#  "'s",
#  'Supply',
#  'Chain',
#  'Act',
#  'coming',
#  'effect',
#  '2023',
#  'force',
#  'large',
#  'public',
#  'organizations',
#  'provide',
#  'visibility',
#  'supply',
#  'chains',
#  'digital',
#  'auditable',
#  'format',
#  'similar',
#  'legislation',
#  'expected',
#  'countries',
#  'The',
#  'key',
#  'challenge',
#  'projects',
#  'insights',
#  'get',
#  'used',
#  'information',
#  'communicated',
#  'ultimate',
#  'suppliers',
#  'producers',
#  'companies',
#  'like',
#  'Unilever',
#  'work',
#  'suppliers',
#  'minimize',
#  'impact',
#  'deforestation',
#  'maintaining',
#  'improving',
#  'well-being',
#  'socioeconomic',
#  'situation',
#  'said',
#  'There',
#  'also',
#  'challenges',
#  'related',
#  'use',
#  'management',
#  'data',
#  'collected',
#  'Muñoz',
#  'said',
#  'It',
#  'needs',
#  'secured',
#  'protected',
#  'aggregated',
#  'certain',
#  'extent',
#  'tech',
#  'vendor',
#  'becomes',
#  'important',
#  'partner',
#  'If',
#  'companies',
#  'like',
#  'Unilever',
#  'use',
#  'applications',
#  'like',
#  'GreenToken',
#  'correctly',
#  'build',
#  'stronger',
#  'relations',
#  'suppliers',
#  'previously',
#  'little',
#  'visibility',
#  'relationship',
#  'said',
#  'Beyond',
#  'also',
#  'building',
#  'credibility',
#  'trust',
#  'enabling',
#  'end-to-end',
#  'transparency',
#  'Muñoz',
#  'said',
#  'Jim',
#  "O'Donnell",
#  'TechTarget',
#  'news',
#  'writer',
#  'covers',
#  'ERP',
#  'enterprise',
#  'applications',
#  'SearchSAP',
#  'SearchERP',
#  'Dig',
#  'Deeper',
#  'SAP',
#  'ERP',
#  'software',
#  'modules',
#  'Taking',
#  'lead',
#  'How',
#  'leaders',
#  'help',
#  'address',
#  'global',
#  'sustainability',
#  'human',
#  'rights',
#  'challenges',
#  'Tackling',
#  'greenwashing',
#  'cloud',
#  'technology',
#  'SAP',
#  'teams',
#  'BCG',
#  'sustainability',
#  'strategy',
#  'By',
#  'Jim',
#  "O'Donnell",
#  'What',
#  "'s",
#  'next',
#  'supply',
#  'chain',
#  'An',
#  'expert',
#  "'s",
#  'take',
#  'By',
#  'Molly',
#  'Driscoll',
#  'Sponsored',
#  'News',
#  'Driving',
#  'IT',
#  'Success',
#  'From',
#  'Edge',
#  'Cloud',
#  'Bottom',
#  'Line',
#  '–HPE',
#  'Supply',
#  'Chain',
#  'Transparency',
#  'Matters',
#  'Now',
#  'More',
#  'Than',
#  'Ever',
#  '–Intel',
#  'Cybersecurity',
#  'Essentials',
#  'Critical',
#  'Infrastructure',
#  '–Dell',
#  'Technologies',
#  'See',
#  'More',
#  'Related',
#  'Content',
#  'Unilever',
#  'partners',
#  'Google',
#  'Cloud',
#  'bolster',
#  'supply',
#  '–',
#  'ComputerWeekly.com',
#  'Google',
#  'Unilever',
#  'partnership',
#  'uses',
#  'AI',
#  'sustainable',
#  '–',
#  'SearchEnterpriseAI',
#  'The',
#  'burning',
#  'issue',
#  'fighting',
#  'forest',
#  'fires',
#  '–',
#  'ComputerWeekly.com',
#  'Latest',
#  'TechTarget',
#  'resources',
#  'ERP',
#  'Oracle',
#  'Data',
#  'Management',
#  'AWS',
#  'Business',
#  'Analytics',
#  'Content',
#  'Management',
#  'HR',
#  'Software',
#  'SearchERP',
#  'NetSuite',
#  'ERP',
#  'adds',
#  'CPQ',
#  'workforce',
#  'management',
#  'applications',
#  'NetSuite',
#  'debuted',
#  'several',
#  'new',
#  'features',
#  'CPQ',
#  'workforce',
#  'management',
#  'embedded',
#  'banking',
#  'warehouse',
#  'management',
#  'cloud',
#  'ERP',
#  'Fair',
#  'Repair',
#  'Act',
#  'could',
#  'help',
#  'spur',
#  'circular',
#  'economy',
#  'model',
#  'New',
#  'regulations',
#  'including',
#  'Fair',
#  'Repair',
#  'Act',
#  'coupled',
#  'factors',
#  'like',
#  'consumer',
#  'demand',
#  'sustainability',
#  'motivating',
#  'RFID',
#  'vs',
#  'IoT',
#  'What',
#  'differences',
#  'Users',
#  'often',
#  'combine',
#  'RFID',
#  'IoT',
#  'two',
#  'technologies',
#  'different',
#  'important',
#  'ways',
#  'Learn',
#  'RFID',
#  'vs',
#  'IoT',
#  'SearchOracle',
#  'Oracle',
#  'sets',
#  'lofty',
#  'national',
#  'EHR',
#  'goal',
#  'Cerner',
#  'acquisition',
#  'With',
#  'Cerner',
#  'acquisition',
#  'Oracle',
#  'sets',
#  'sights',
#  'creating',
#  'national',
#  'anonymized',
#  'patient',
#  'database',
#  'road',
#  'filled',
#  'With',
#  'Cerner',
#  'Oracle',
#  'Cloud',
#  'Infrastructure',
#  'gets',
#  'boost',
#  'Oracle',
#  'plans',
#  ...]

# %% [markdown]
# ## 4 - **Counter** to count objects
# In collections, you’ll find a class specially designed to count several different objects in one go. This class is conveniently called **Counter**.
#
# https://docs.python.org/3/library/collections.html

# %%
from collections import Counter

# generates a collection where elements are stored as dictionary keys and their counts are stored as dictionary values - key:value pairs.
item_count = Counter(filtered_text)
print(item_count, "\n")

# Converts the list to a list of (elements, counter) pairs
text_items = item_count.items() 

# Return a list of the n most common elements and their counts from the most common to the least.
common_text_item = item_count.most_common(10)
common_text_item
# Out:
# Counter({'Unilever': 22, 'palm': 20, 'oil': 20, 'supply': 15, 'chain': 15, 'said': 14, 'The': 13, "'s": 12, 'sustainability': 10, 'technology': 10, 'data': 10, 'like': 9, 'GreenToken': 8, 'deforestation': 8, 'companies': 8, 'management': 8, 'used': 7, 'organizations': 7, 'ERP': 6, 'issues': 6, 'forest': 6, 'Muñoz': 6, 'Oracle': 6, 'SAP': 5, 'products': 5, 'production': 5, 'transparency': 5, 'company': 5, 'new': 5, 'report': 5, 'use': 5, 'AWS': 5, 'DataOps': 5, 'sharing': 5, 'TechTarget': 4, 'News': 4, 'More': 4, 'Cloud': 4, 'blockchain': 4, 'help': 4, "n't": 4, 'consumer': 4, 'Wilcox': 4, 'according': 4, 'RAN': 4, 'also': 4, 'coming': 4, 'Supply': 4, 'important': 4, 'cloud': 4, 'Cerner': 4, 'users': 4, 'EKS': 4, 'file': 4, 'best': 4, 'SearchSAP': 3, 'Network': 3, 'Content': 3, 'Management': 3, 'Infrastructure': 3, 'ensure': 3, 'comes': 3, 'responsible': 3, 'rainforest': 3, 'By': 3, 'Jim': 3, "O'Donnell": 3, 'practices': 3, 'fruit': 3, 'plantations': 3, 'Aceh': 3, 'expansion': 3, 'industry': 3, 'sustainable': 3, 'sourcing': 3, 'digital': 3, 'plantation': 3, 'create': 3, 'footprint': 3, 'address': 3, 'ha': 3, 'risks': 3, 'complex': 3, 'Palm': 3, 'certifications': 3, 'human': 3, 'rights': 3, 'track': 3, 'Jain': 3, 'materials': 3, 'information': 3, 'With': 3, 'A': 3, 'Act': 3, 'suppliers': 3, 'vendor': 3, 'applications': 3, 'build': 3, 'How': 3, 'Google': 3, '–': 3, 'HR': 3, 'model': 3, 'RFID': 3, 'vs': 3, 'IoT': 3, 'Learn': 3, 'Amazon': 3, 'product': 3, 'security': 3, 'access': 2, 'Features': 2, 'Tips': 2, 'Answers': 2, 'Definitions': 2, 'Guides': 2, 'Opinions': 2, 'Photo': 2, 'Stories': 2, 'Quizzes': 2, 'Tutorials': 2, 'Sponsored': 2, 'Software': 2, 'Data': 2, 'All': 2, 'sources': 2, 'contribute': 2, 'loss': 2, '2022': 2, 'startup': 2, 'provides': 2, 'blockchain-based': 2, 'focus': 2, 'including': 2, 'notably': 2, 'Andrew': 2, 'Leuser': 2, 'two': 2, 'areas': 2, 'accelerated': 2, 'senior': 2, 'manager': 2, 'land': 2, 'communities': 2, 'ways': 2, 'provide': 2, 'traceability': 2, 'improving': 2, 'satellite': 2, 'AI': 2, 'conversion': 2, 'forests': 2, 'potential': 2, 'future': 2, 'along': 2, 'goods': 2, 'face': 2, 'increased': 2, 'public': 2, 'pressure': 2, 'Companies': 2, 'countries': 2, 'regulations': 2, 'U.S': 2, 'business': 2, 'operations': 2, 'chains': 2, 'long': 2, 'make': 2, 'sustainably': 2, 'Oil': 2, 'source': 2, '2021': 2, 'climate': 2, 'conflict': 2, 'across': 2, 'need': 2, 'change': 2, 'made': 2, 'commitment': 2, 'One': 2, 'strategy': 2, 'meet': 2, 'using': 2, 'Nitin': 2, 'facts': 2, 'raw': 2, 'include': 2, 'attributes': 2, 'producers': 2, 'It': 2, 'uses': 2, 'tokens': 2, 'Marta': 2, 'impact': 2, 'lead': 2, 'Europe': 2, 'For': 2, 'Chain': 2, '2023': 2, 'visibility': 2, 'work': 2, 'There': 2, 'challenges': 2, 'enabling': 2, 'SearchERP': 2, 'Dig': 2, 'leaders': 2, 'What': 2, 'IT': 2, 'See': 2, 'bolster': 2, 'ComputerWeekly.com': 2, 'Business': 2, 'NetSuite': 2, 'adds': 2, 'CPQ': 2, 'workforce': 2, 'several': 2, 'features': 2, 'warehouse': 2, 'Fair': 2, 'Repair': 2, 'could': 2, 'sets': 2, 'national': 2, 'EHR': 2, 'acquisition': 2, 'Supreme': 2, 'Court': 2, 'copyright': 2, 'trends': 2, 'looking': 2, 'accurate': 2, 'team': 2, 'Lufthansa': 2, 'Control': 2, 'Tower': 2, 'aims': 2, 'service': 2, 'pricing': 2, 'deploy': 2, 'Kubernetes': 2, 'enable': 2, 'capabilities': 2, 'secure': 2, 'Florida': 2, 'may': 2, 'makes': 2, 'workweek': 2, 'Us': 2, 'Policy': 2, 'Search': 1, 'Sign-up': 1, 'Start': 1, 'free': 1, 'unlimited': 1, 'Login': 1, 'Register': 1, 'Techtarget': 1, 'Webinars': 1, 'Essential': 1, 'Podcasts': 1, 'Communities': 1, 'Topic': 1, 'Developer': 1, 'Tools': 1, 'HANA': 1, 'Topics': 1, 'Follow': 1, 'phive2015': 1, 'stock.adobe.com': 1, 'pursues': 1, 'deploys': 1, 'blockchain-enabled': 1, 'Share': 1, 'item': 1, 'network': 1, 'Writer': 1, 'Published': 1, '30': 1, 'Mar': 1, 'giant': 1, 'hoping': 1, 'improve': 1, 'implementing': 1, 'derived': 1, 'tree': 1, 'thousands': 1, 'non-food': 1, 'soaps': 1, 'shampoos': 1, 'However': 1, 'ris ...
# [('Unilever', 22),
#  ('palm', 20),
#  ('oil', 20),
#  ('supply', 15),
#  ('chain', 15),
#  ('said', 14),
#  ('The', 13),
#  ("'s", 12),
#  ('sustainability', 10),
#  ('technology', 10)]

# %% [markdown]
# ## 5 - Storing text items in a pandas Dataframe & Plot graph

# %%
import pandas as pd

#Create DataFrame and Storing it in variable df

df = pd.DataFrame(item_count.most_common(15), columns = ['word', 'count'])
print(df)
## Visualise the Dataframe
df.plot.bar(x='word', y='count', legend=False, figsize=(8,8))
# Out:
#               word  count
# 0         Unilever     22
# 1             palm     20
# 2              oil     20
# 3           supply     15
# 4            chain     15
# 5             said     14
# 6              The     13
# 7               's     12
# 8   sustainability     10
# 9       technology     10
# 10            data     10
# 11            like      9
# 12      GreenToken      8
# 13   deforestation      8
# 14       companies      8

# %% [markdown]
# ## 6 - Generate a simple WordCloud
# * https://towardsdatascience.com/simple-wordcloud-in-python-2ae54a9f58e5/
# * https://www.geeksforgeeks.org/generating-word-cloud-python/

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %matplotlib inline

# Create and generate a word cloud image

####
# Create the wordcloud object
wordcloud = WordCloud(width=1000, height=1000, margin=0, max_words=250).generate(str(item_count))
####


#set figure size
plt.figure(figsize=(7, 7))
#show image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
